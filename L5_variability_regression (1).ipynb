# %%
#load tidyverse for some needed packages
library(tidyverse)
#load our dataset
co2 <- read.csv("co2gdp_all.csv")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#examine data
co2
# Out:
#     countryname            countrycode gdppercapitapppconstant2005inter
# 1                                             NA
# 2                                             NA
# 3   Afghanistan            AFG                NA
# 4   Albania                ALB          5.211804
# 5   Algeria                DZA          5.844023
# 6   American Samoa         ASM                NA
# 7   Andorra                ADO                NA
# 8   Angola                 AGO          3.182347
# 9   Antigua and Barbuda    ATG         14.195593
# 10  Argentina              ARG         10.002686
# 11  Armenia                ARM          3.642952
# 12  Aruba                  ABW                NA
# 13  Australia              AUS         33.614812
# 14  Austria                AUT         33.632455
# 15  Azerbaijan             AZE          3.662137
# 16  Bahamas, The           BHS                NA
# 17  Bahrain                BHR         31.668008
# 18  Bangladesh             BGD          1.026554
# 19  Barbados               BRB                NA
# 20  Belarus                BLR          7.765218
# 21  Belgium                BEL         31.536180
# 22  Belize                 BLZ          7.355714
# 23  Benin                  BEN          1.217001
# 24  Bermuda                BMU                NA
# 25  Bhutan                 BTN          3.485570
# 26  Bolivia                BOL          3.639278
# 27  Bosnia and Herzegovina BIH          5.679852
# 28  Botswana               BWA         11.686347
# 29  Brazil                 BRA          8.347048
# 30  Brunei Darussalam      BRN         47.851191
# ⋮   ⋮                      ⋮           ⋮
# 183 Suriname               SUR          6.9394523
# 184 Swaziland              SWZ          4.4026923
# 185 Sweden                 SWE         31.2240210
# 186 Switzerland            CHE         34.7380910
# 187 Syrian Arab Republic   SYR          3.9344713
# 188 Tajikistan             TJK          1.4030010
# 189 Tanzania               TZA          0.8965171
# 190 Thailand               THA          6.8051831
# 191 Timor-Leste            TMP          2.2942588
# 192 Togo                   TGO          0.7530683
# 193 Tonga                  TON          5.0918331
# 194 Trinidad and Tobago    TTO         14.3028590
# 195 Tunisia                TUN          6.1823923
# 196 Turkey                 TUR          7.3438409
# 197 Turkmenistan           TKM                 NA
# 198 Uganda                 UGA          0.8204411
# 199 Ukraine                UKR          5.3969174
# 200 United Arab Emirates   ARE         32.0895760
# 201 United Kingdom         GBR         30.9784310
# 202 United States          USA         40.9004410
# 203 Uruguay                URY          8.7004924
# 204 Uzbekistan             UZB          1.8982633
# 205 Vanuatu                VUT          3.3642288
# 206 Venezuela, RB          VEN          9.1064900
# 207 Vietnam                VNM          2.0018155
# 208 Virgin Islands (U.S.)  VIR                 NA
# 209 West Bank and Gaza     WBG          3.4884581
# 210 Yemen, Rep.            YEM          2.1554507
# 211 Zambia                 ZMB          1.1334001
# 212 Zimbabwe               ZWE                 NA
#     co2percaptons gdp_dollars
# 1           NA           NA
# 2           NA           NA
# 3           NA           NA
# 4    1.1709810     5211.804
# 5    5.9886600     5844.023
# 6           NA           NA
# 7           NA           NA
# 8    0.5046268     3182.347
# 9    5.0510570    14195.590
# 10   3.6917790    10002.690
# 11   1.2041070     3642.952
# 12  21.7560000           NA
# 13  16.2156100    33614.810
# 14   8.5365590    33632.460
# 15   3.7726290     3662.137
# 16   6.2859900           NA
# 17  23.8442200    31668.010
# 18   0.2466768     1026.554
# 19   4.3568020           NA
# 20   6.5989760     7765.218
# 21   9.6559930    31536.180
# 22   2.7997450     7355.714
# 23   0.2899544     1217.001
# 24   8.6773530           NA
# 25   0.6643090     3485.570
# 26   0.7733368     3639.278
# 27   3.9900420     5679.852
# 28   2.3672010    11686.350
# 29   1.7985130     8347.048
# 30  24.0696200    47851.190
# ⋮   ⋮             ⋮
# 183  5.0759690     6939.4520
# 184  0.8537311     4402.6920
# 185  5.8924970    31224.0200
# 186  5.4700260    34738.0900
# 187  3.7173340     3934.4710
# 188  0.7731102     1403.0010
# 189  0.1159214      896.5172
# 190  4.2810190     6805.1830
# 191  0.1901536     2294.2590
# 192  0.3801268      753.0684
# 193  1.1841080     5091.8330
# 194 24.6580800    14302.8600
# 195  2.3020060     6182.3920
# 196  3.1753150     7343.8410
# 197  8.7470670            NA
# 198  0.0650849      820.4410
# 199  6.9490440     5396.9170
# 200 37.7628100    32089.5800
# 201  9.8060090    30978.4300
# 202 20.5832500    40900.4400
# 203  1.6574700     8700.4920
# 204  5.3271610     1898.2630
# 205  0.4187921     3364.2290
# 206  6.6011670     9106.4900
# 207  1.2016690     2001.8160
# 208         NA            NA
# 209         NA     3488.4580
# 210  1.0301450     2155.4510
# 211  0.2028175     1133.4000
# 212  0.8099231            NA

# %%
#eliminate missing values
co2 <-subset(co2, is.na(co2[,"co2percaptons"])==F)
co2 <-subset(co2, is.na(co2[,"gdp_dollars"])==F)

# %%
co2
# Out:
#     countryname                    countrycode gdppercapitapppconstant2005inter
# 4   Albania                        ALB          5.2118040
# 5   Algeria                        DZA          5.8440231
# 8   Angola                         AGO          3.1823467
# 9   Antigua and Barbuda            ATG         14.1955930
# 10  Argentina                      ARG         10.0026860
# 11  Armenia                        ARM          3.6429522
# 13  Australia                      AUS         33.6148120
# 14  Austria                        AUT         33.6324550
# 15  Azerbaijan                     AZE          3.6621367
# 17  Bahrain                        BHR         31.6680080
# 18  Bangladesh                     BGD          1.0265542
# 20  Belarus                        BLR          7.7652180
# 21  Belgium                        BEL         31.5361800
# 22  Belize                         BLZ          7.3557138
# 23  Benin                          BEN          1.2170009
# 25  Bhutan                         BTN          3.4855703
# 26  Bolivia                        BOL          3.6392784
# 27  Bosnia and Herzegovina         BIH          5.6798521
# 28  Botswana                       BWA         11.6863470
# 29  Brazil                         BRA          8.3470476
# 30  Brunei Darussalam              BRN         47.8511910
# 31  Bulgaria                       BGR          8.7334112
# 32  Burkina Faso                   BFA          1.0218450
# 33  Burundi                        BDI          0.3287862
# 34  Cambodia                       KHM          1.2908664
# 35  Cameroon                       CMR          1.9960312
# 36  Canada                         CAN         34.3173860
# 37  Cape Verde                     CPV          2.3058479
# 39  Central African Republic       CAF          0.6505574
# 40  Chad                           TCD          1.4094431
# ⋮   ⋮                              ⋮           ⋮
# 179 St. Kitts and Nevis            KNA         13.4077790
# 180 St. Lucia                      LCA          8.8219954
# 181 St. Vincent and the Grenadines VCT          6.7312564
# 182 Sudan                          SDN          1.6081888
# 183 Suriname                       SUR          6.9394523
# 184 Swaziland                      SWZ          4.4026923
# 185 Sweden                         SWE         31.2240210
# 186 Switzerland                    CHE         34.7380910
# 187 Syrian Arab Republic           SYR          3.9344713
# 188 Tajikistan                     TJK          1.4030010
# 189 Tanzania                       TZA          0.8965171
# 190 Thailand                       THA          6.8051831
# 191 Timor-Leste                    TMP          2.2942588
# 192 Togo                           TGO          0.7530683
# 193 Tonga                          TON          5.0918331
# 194 Trinidad and Tobago            TTO         14.3028590
# 195 Tunisia                        TUN          6.1823923
# 196 Turkey                         TUR          7.3438409
# 198 Uganda                         UGA          0.8204411
# 199 Ukraine                        UKR          5.3969174
# 200 United Arab Emirates           ARE         32.0895760
# 201 United Kingdom                 GBR         30.9784310
# 202 United States                  USA         40.9004410
# 203 Uruguay                        URY          8.7004924
# 204 Uzbekistan                     UZB          1.8982633
# 205 Vanuatu                        VUT          3.3642288
# 206 Venezuela, RB                  VEN          9.1064900
# 207 Vietnam                        VNM          2.0018155
# 210 Yemen, Rep.                    YEM          2.1554507
# 211 Zambia                         ZMB          1.1334001
#     co2percaptons gdp_dollars
# 4    1.1709810     5211.8040
# 5    5.9886600     5844.0230
# 8    0.5046268     3182.3470
# 9    5.0510570    14195.5900
# 10   3.6917790    10002.6900
# 11   1.2041070     3642.9520
# 13  16.2156100    33614.8100
# 14   8.5365590    33632.4600
# 15   3.7726290     3662.1370
# 17  23.8442200    31668.0100
# 18   0.2466768     1026.5540
# 20   6.5989760     7765.2180
# 21   9.6559930    31536.1800
# 22   2.7997450     7355.7140
# 23   0.2899544     1217.0010
# 25   0.6643090     3485.5700
# 26   0.7733368     3639.2780
# 27   3.9900420     5679.8520
# 28   2.3672010    11686.3500
# 29   1.7985130     8347.0480
# 30  24.0696200    47851.1900
# 31   5.4646070     8733.4110
# 32   0.0810860     1021.8450
# 33   0.0290492      328.7862
# 34   0.0389787     1290.8660
# 35   0.2202921     1996.0310
# 36  19.9703300    34317.3900
# 37   0.5548083     2305.8480
# 39   0.0612969      650.5574
# 40   0.0126951     1409.4430
# ⋮   ⋮             ⋮
# 179  2.6506870    13407.7800
# 180  2.2550700     8821.9950
# 181  1.6693000     6731.2560
# 182  0.2866941     1608.1890
# 183  5.0759690     6939.4520
# 184  0.8537311     4402.6920
# 185  5.8924970    31224.0200
# 186  5.4700260    34738.0900
# 187  3.7173340     3934.4710
# 188  0.7731102     1403.0010
# 189  0.1159214      896.5172
# 190  4.2810190     6805.1830
# 191  0.1901536     2294.2590
# 192  0.3801268      753.0684
# 193  1.1841080     5091.8330
# 194 24.6580800    14302.8600
# 195  2.3020060     6182.3920
# 196  3.1753150     7343.8410
# 198  0.0650849      820.4410
# 199  6.9490440     5396.9170
# 200 37.7628100    32089.5800
# 201  9.8060090    30978.4300
# 202 20.5832500    40900.4400
# 203  1.6574700     8700.4920
# 204  5.3271610     1898.2630
# 205  0.4187921     3364.2290
# 206  6.6011670     9106.4900
# 207  1.2016690     2001.8160
# 210  1.0301450     2155.4510
# 211  0.2028175     1133.4000

# %%
#generate random samples - runif draws a uniform random number.  10% of these will be less than 0.1
#drawing sample 1
co2[,"sample1"]<-runif(nrow(co2))<0.1
#drawing sample 2
co2[,"sample2"]<-runif(nrow(co2))<0.1
#for simplicity, make a new dataset with each of our samples
co2_sample1 <-subset(co2,co2[,"sample1"])
co2_sample2 <-subset(co2, co2[,"sample2"])

# %%
#view sample 1
co2_sample1
# Out:
#     countryname          countrycode gdppercapitapppconstant2005inter
# 11  Armenia              ARM          3.6429522
# 14  Austria              AUT         33.6324550
# 22  Belize               BLZ          7.3557138
# 50  Croatia              HRV         12.6871590
# 53  Czech Republic       CZE         19.0946200
# 61  Equatorial Guinea    GNQ         27.3329640
# 111 Liberia              LBR          0.3045976
# 144 Niger                NER          0.5817673
# 147 Norway               NOR         46.6101310
# 159 Qatar                QAT         69.4518830
# 160 Romania              ROM          8.9776587
# 187 Syrian Arab Republic SYR          3.9344713
#     co2percaptons gdp_dollars sample1 sample2
# 11   1.2041070     3642.9520  TRUE    FALSE
# 14   8.5365590    33632.4600  TRUE    FALSE
# 22   2.7997450     7355.7140  TRUE     TRUE
# 50   5.2848580    12687.1600  TRUE    FALSE
# 53  11.4516700    19094.6200  TRUE    FALSE
# 61  11.4645700    27332.9600  TRUE    FALSE
# 111  0.1400228      304.5977  TRUE    FALSE
# 144  0.0946645      581.7673  TRUE    FALSE
# 147 19.0602500    46610.1300  TRUE    FALSE
# 159 69.1590600    69451.8800  TRUE    FALSE
# 160  4.1662310     8977.6590  TRUE    FALSE
# 187  3.7173340     3934.4710  TRUE    FALSE

# %%
#view sample 2
co2_sample2
# Out:
#     countryname            countrycode gdppercapitapppconstant2005inter
# 22  Belize                 BLZ          7.3557138
# 27  Bosnia and Herzegovina BIH          5.6798521
# 52  Cyprus                 CYP         24.1768500
# 71  Gambia, The            GMB          1.0570558
# 72  Georgia                GEO          3.1807839
# 80  Guinea                 GIN          1.0895063
# 99  Kazakhstan             KAZ          8.0007600
# 116 Macao, China           MAC         34.8943900
# 118 Madagascar             MDG          0.8194212
# 120 Malaysia               MYS         11.3259060
# 151 Panama                 PAN          8.0332662
# 166 Saudi Arabia           SAU         20.5304710
# 169 Seychelles             SYC         14.1845960
# 200 United Arab Emirates   ARE         32.0895760
#     co2percaptons gdp_dollars sample1 sample2
# 22   2.7997450     7355.7140   TRUE   TRUE
# 27   3.9900420     5679.8520  FALSE   TRUE
# 52   9.1154140    24176.8500  FALSE   TRUE
# 71   0.1819055     1057.0560  FALSE   TRUE
# 72   0.8652728     3180.7840  FALSE   TRUE
# 80   0.1513676     1089.5060  FALSE   TRUE
# 99  13.3284700     8000.7600  FALSE   TRUE
# 116  4.7155260    34894.3900  FALSE   TRUE
# 118  0.1504813      819.4212  FALSE   TRUE
# 120  7.0430560    11325.9100  FALSE   TRUE
# 151  1.7811150     8033.2660  FALSE   TRUE
# 166 13.6762500    20530.4700  FALSE   TRUE
# 169  6.6156000    14184.6000  FALSE   TRUE
# 200 37.7628100    32089.5800  FALSE   TRUE

# %%
#scatter plot sample 1
plot(co2_sample1[,"gdppercapitapppconstant2005inter"],co2_sample1[,"co2percaptons"])
# Out:
# plot without title

# %%
#scatter plot sample 2
plot(co2_sample2[,"gdppercapitapppconstant2005inter"],co2_sample2[,"co2percaptons"])
# Out:
# plot without title

# %%
#regress co2 on gdp in sample 1
s1_reg <- lm(co2percaptons ~gdppercapitapppconstant2005inter, data = co2_sample1)
s1_reg
# Out:
# Call:
# lm(formula = co2percaptons ~ gdppercapitapppconstant2005inter,
#     data = co2_sample1)
#
# Coefficients:
#                      (Intercept)  gdppercapitapppconstant2005inter
#                          -4.0476                            0.7947

# %%
#regress co2 on gdp in sample 2
s2_reg <- lm(co2percaptons ~gdppercapitapppconstant2005inter, data = co2_sample2)
s2_reg
# Out:
# Call:
# lm(formula = co2percaptons ~ gdppercapitapppconstant2005inter,
#     data = co2_sample2)
#
# Coefficients:
#                      (Intercept)  gdppercapitapppconstant2005inter
#                           0.2906                            0.5690

# %%
#view standard errors
summary(s1_reg)
# Out:
# Call:
# lm(formula = co2percaptons ~ gdppercapitapppconstant2005inter,
#     data = co2_sample1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -14.144  -2.115   1.040   3.746  18.012
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                       -4.0476     3.6012  -1.124    0.287
# gdppercapitapppconstant2005inter   0.7947     0.1276   6.230 9.76e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.034 on 10 degrees of freedom
# Multiple R-squared:  0.7951,	Adjusted R-squared:  0.7747
# F-statistic: 38.81 on 1 and 10 DF,  p-value: 9.755e-05

# %%
library(sandwich)
library(lmtest)
# Out:
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
coeftest(s1_reg, vcov = vcovHC)
# Out:
# t test of coefficients:
#
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      -4.04763    4.99782 -0.8099   0.4369
# gdppercapitapppconstant2005inter  0.79472    0.44341  1.7923   0.1033
